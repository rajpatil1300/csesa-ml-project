# %%
import json
import glob
import os
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

JSON_FOLDER = "StructuredRegulatoryDocuments"
TXT_FOLDER = "Testset"

print("Libraries imported and paths set.")
# Out:
# Libraries imported and paths set.

# %%
def load_knowledge_base(folder_path):
    # Reads all JSON files from the specified folder
    print(f"Loading regulatory rules from: {folder_path}...")
    data_rows = []
    
    json_files = glob.glob(os.path.join(folder_path, "*.json"))
    
    if not json_files:
        print(f"Error: No JSON files found in {folder_path}")
        return pd.DataFrame()

    for path in json_files:
        try:
            with open(path, "r", encoding="utf-8") as f:
                data = json.load(f)
                for item in data:
                    # Extract only valid passages
                    if item.get("Passage") and len(item["Passage"].strip()) > 10:
                        data_rows.append({
                            "source_file": os.path.basename(path),
                            "rule_id": item.get("PassageID", "Unknown"),
                            "text": item["Passage"]
                        })
        except Exception as e:
            print(f"Error reading {path}: {e}")

    print(f"Successfully loaded {len(data_rows)} regulations.")
    return pd.DataFrame(data_rows)

def load_test_documents(folder_path):
    # Reads all text files from the specified folder
    print(f"Loading test documents from: {folder_path}...")
    docs = {}
    
    txt_files = glob.glob(os.path.join(folder_path, "*.txt"))
    
    if not txt_files:
        print(f"Error: No TXT files found in {folder_path}")
        return {}

    for path in txt_files:
        with open(path, "r", encoding="utf-8") as f:
            docs[os.path.basename(path)] = f.read()
            
    return docs

print("Data loading functions defined.")
# Out:
# Data loading functions defined.

# %%
class ComplianceMatcher:
    def __init__(self, df):
        self.df = df
        # Initialize the Vectorizer to convert text to numbers
        self.vectorizer = TfidfVectorizer(stop_words="english")
        
        # Train the model on the Regulatory Knowledge Base
        print("Training NLP model on regulatory rules...")
        self.rule_vectors = self.vectorizer.fit_transform(self.df["text"])

    def find_relevant_rules(self, doc_text, top_k=3, threshold=0.15):
        results = []
        # Split document into paragraphs for granular analysis
        paragraphs = [p for p in doc_text.split("\n\n") if len(p) > 50]

        for para in paragraphs:
            para_vec = self.vectorizer.transform([para])
            
            # Compare paragraph against all rules
            scores = cosine_similarity(para_vec, self.rule_vectors).flatten()
            
            # Find top matches
            best_indices = scores.argsort()[-top_k:][::-1]

            matches = []
            for idx in best_indices:
                score = scores[idx]
                if score > threshold:
                    row = self.df.iloc[idx]
                    matches.append({
                        "rule_id": row["rule_id"],
                        "source": row["source_file"],
                        "rule_text": row["text"],
                        "confidence": round(score * 100, 2)
                    })

            if matches:
                results.append({
                    "paragraph_snippet": para[:200] + "...",
                    "matches": matches
                })

        return results

print("Compliance Engine class defined.")
# Out:
# Compliance Engine class defined.

# %%
# 1. Load the Data
kb_df = load_knowledge_base(JSON_FOLDER)
documents = load_test_documents(TXT_FOLDER)

# 2. Check if data exists
if kb_df.empty or not documents:
    print("Execution Stopped: Missing Data. Please check your folders.")
else:
    # 3. Initialize Engine
    matcher = ComplianceMatcher(kb_df)

    # 4. Run Analysis
    print("\n" + "="*60)
    print("STARTING COMPLIANCE AUDIT REPORT")
    print("="*60)

    for doc_name, content in documents.items():
        print(f"\nAnalyzing Document: {doc_name}")
        print("-" * 30)
        
        analysis_results = matcher.find_relevant_rules(content)
        
        if not analysis_results:
            print("  No significant regulatory risks found.")
        else:
            for item in analysis_results:
                print(f"\n[Document Section]: \"{item['paragraph_snippet']}\"")
                
                for m in item['matches']:
                    print(f"   >>> Match: Rule {m['rule_id']} (Confidence: {m['confidence']}%)")
                    print(f"       Source: {m['source']}")
                    print(f"       Text: {m['rule_text'][:150]}...")
# Out:
# Loading regulatory rules from: StructuredRegulatoryDocuments...
# Successfully loaded 12857 regulations.
# Loading test documents from: Testset...
# Training NLP model on regulatory rules...
#
# ============================================================
# STARTING COMPLIANCE AUDIT REPORT
# ============================================================
#
# Analyzing Document: T1.txt
# ------------------------------
#
# [Document Section]: "Inter-Affiliate Service and Financial Support Agreement
# Preamble: This Agreement is entered into to formalize the business and financial relationships between related entities within the corporate Gro..."
#    >>> Match: Rule Part 17.202.(3) (Confidence: 35.62%)
#        Source: 17.json
#        Text: A direction to an Affiliate under subsection ‎(2) may include, without limitation, a requirement that the Affiliate—
# (a)	limit any activities it under...
#    >>> Match: Rule Part 17.202.(2) (Confidence: 31.03%)
#        Source: 17.json
#        Text: The Regulator may direct an Affiliate of a Financial Institution or Recognised Body to take Specified steps or not to carry out Specified activities i...
#    >>> Match: Rule Part 3.23.(5) (Confidence: 26.79%)
#        Source: 17.json
#        Text: If the person against whom the Agreement is unenforceable—
# (a)	elects not to perform the Agreement; or
# (b)	as a result of this section, recovers money...
#
# [Document Section]: "Alpha Parent Holdings (APH): The primary holding company of the Group (Parent)...."
#    >>> Match: Rule Part 3.Chapter 2.11.(1) (Confidence: 41.99%)
#        Source: 14.json
#        Text: The Regulator may require an ADGM Parent Institution to prepare a Group Resolution Plan for the Group headed by the ADGM Parent Institution as a whole...
#    >>> Match: Rule 8.2.1.Guidance.2. (Confidence: 41.14%)
#        Source: 12.json
#        Text: An Insurer may also consider together Groups whose Parents are all members of the same Group, except for any Group of which the Insurer is the Parent....
#    >>> Match: Rule Part 3.Chapter 1.8.(1) (Confidence: 39.56%)
#        Source: 14.json
#        Text: The Regulator may require an ADGM Parent Institution to prepare and submit to the Regulator a Group Recovery Plan for the Group headed by the ADGM Par...
#
# [Document Section]: "Beta Investment Firm (BIF): A regulated financial subsidiary of the Parent (Subsidiary)...."
#    >>> Match: Rule 3.2.8 (Confidence: 55.15%)
#        Source: 27.json
#        Text: Subsidiary of a non-ADGM firm. A firm carrying on Regulated Activities as a Subsidiary of an unregulated non-ADGM parent company may be subject to our...
#    >>> Match: Rule 3.2.6 (Confidence: 45.59%)
#        Source: 27.json
#        Text: Subsidiary of a non-ADGM firm. We will be the host regulator for the purpose of prudential supervision of a firm which is an ADGM incorporated Subsidi...
#    >>> Match: Rule Part 6.Chapter 4.65.(5) (Confidence: 43.6%)
#        Source: 14.json
#        Text: Where an Investment Firm, ADGM Parent Undertaking or ADGM Subsidiary meets the Resolution Conditions and the Regulator decides to apply a Resolution T...
#
# [Document Section]: "Section 3: Liquidity and Capital Support
# 3.1 Intragroup Financial Support Obligation APH agrees to provide BIF with liquidity support up to $150,000,000 USD, to be drawn upon BIF determining that its ..."
#    >>> Match: Rule 9 (Confidence: 32.86%)
#        Source: 13.json
#        Text: LIQUIDITY RISK...
#    >>> Match: Rule 4.7.27.Guidance (Confidence: 32.86%)
#        Source: 10.json
#        Text: Liquidity risk....
#    >>> Match: Rule 9.3 (Confidence: 29.08%)
#        Source: 13.json
#        Text: Liquidity requirements...
#
# [Document Section]: "3.2 Recipient Obligation BIF acknowledges that the preferential nature of this financial support, including terms not tied to open market pricing, is necessary for the immediate benefit of the Group a..."
#    >>> Match: Rule 20.14 (Confidence: 21.65%)
#        Source: 3.json
#        Text: Reporting and Risk mitigation...
#    >>> Match: Rule 19.23 (Confidence: 21.65%)
#        Source: 3.json
#        Text: Risk mitigation and Reporting...
#    >>> Match: Rule Part 6.Chapter 3.59.(1) (Confidence: 20.51%)
#        Source: 14.json
#        Text: The Regulator shall have the power to require an Institution in Resolution, or any of its Group Entities, to provide any services or facilities (exclu...
#
# [Document Section]: "Section 4: Management and Reporting
# 4.1 Management Reports The Management of BIF shall provide a comprehensive annual report to APH detailing the state of its internal recovery plans and summarizing a..."
#    >>> Match: Rule Part 3.Chapter 1 (Confidence: 35.72%)
#        Source: 14.json
#        Text: Recovery Plans...
#    >>> Match: Rule 164) (Confidence: 33.06%)
#        Source: 28.json
#        Text: EARNINGS GUIDANCE
# Significant differences to earnings guidance
# Market expectations may also have been set, or modified, by an ‘outlook statement’ in a...
#    >>> Match: Rule Part 3.Chapter 1.8. (Confidence: 32.06%)
#        Source: 14.json
#        Text: Group Recovery Plans...
#
# [Document Section]: "Section 5: Termination and Default
# 5.1 Events of Default It shall constitute an immediate Event of Default, allowing APH to terminate this Agreement and demand repayment of all outstanding obligations..."
#    >>> Match: Rule 4.5 (Confidence: 39.95%)
#        Source: 10.json
#        Text: Default Rules...
#    >>> Match: Rule 3.10 (Confidence: 39.95%)
#        Source: 10.json
#        Text: Default Rules...
#    >>> Match: Rule Part 6.Chapter 3.63. (Confidence: 37.2%)
#        Source: 14.json
#        Text: Default Event Provisions...
#
# [Document Section]: "IN WITNESS WHEREOF, the parties have executed this Agreement as of the date of signing...."
#    >>> Match: Rule 3.3.2.(c) (Confidence: 21.13%)
#        Source: 3.json
#        Text: An Authorised Person may rely on a Client Agreement executed other than by the Authorised Person in the following circumstances:
# (i)	An Authorised Per...
#    >>> Match: Rule 3.2.Guidance.1. (Confidence: 19.57%)
#        Source: 1.json
#        Text: The point at which a Person becomes a customer will vary from business to business. However, the Regulator considers that it would usually occur at or...
#    >>> Match: Rule Part 3.23.(5) (Confidence: 18.2%)
#        Source: 17.json
#        Text: If the person against whom the Agreement is unenforceable—
# (a)	elects not to perform the Agreement; or
# (b)	as a result of this section, recovers money...
#
# Analyzing Document: T3.txt
# ------------------------------
#
# [Document Section]: "Sample Non-Compliant New Individual Account Application (Excerpt)..."
#    >>> Match: Rule SECTION VIII.C.12. (Confidence: 43.05%)
#        Source: 40.json
#        Text: The term “New Individual Account” means a New Account held by one or more individuals....
#    >>> Match: Rule SECTION VIII.C.16. (Confidence: 35.77%)
#        Source: 40.json
#        Text: The term “New Entity Account” means a New Account held by one or more Entities....
#    >>> Match: Rule SECTION IV (Confidence: 33.2%)
#        Source: 40.json
#        Text: DUE DILIGENCE FOR NEW INDIVIDUAL ACCOUNTS
#
# The following procedures apply with respect to New Individual Accounts.
# ...
#
# [Document Section]: "Section: Tax Residency Self-Certification & Due Diligence..."
#    >>> Match: Rule 6. (Confidence: 53.38%)
#        Source: 40.json
#        Text: UAE TAX RESIDENCY DEFINITIONS
# For the purposes of the reasonableness test, a Reporting Financial Institution may deem the statement of “UAE tax reside...
#    >>> Match: Rule 7.A. (Confidence: 49.08%)
#        Source: 40.json
#        Text: Provision of false self-certification
# ...
#    >>> Match: Rule SECTION IX.B. (Confidence: 47.8%)
#        Source: 40.json
#        Text: Self-certification for New Entity Accounts
# ...
#
# [Document Section]: " Field ID  Field Name  Applicant Response  Due Diligence Action
#  :---  :---  :---  :---
#  TAX-01  Jurisdiction(s) of Residence for Tax Purposes (Self-Certification)  Germany, Italy, and UAE  None. Se..."
#    >>> Match: Rule 6.1. (Confidence: 53.37%)
#        Source: 40.json
#        Text: with regard to New Individual Accounts:
# (a)	documentary evidence of a valid UAE residency visa is provided by a Declaring Person; and
# (b)	Enhanced Due...
#    >>> Match: Rule 6. (Confidence: 46.22%)
#        Source: 40.json
#        Text: UAE TAX RESIDENCY DEFINITIONS
# For the purposes of the reasonableness test, a Reporting Financial Institution may deem the statement of “UAE tax reside...
#    >>> Match: Rule 6.2. (Confidence: 40.68%)
#        Source: 40.json
#        Text: with regard to New Entity Accounts:
# (a)	documentary evidence of valid trade license, registration certificate or similar issued by the relevant UAE li...
#
# [Document Section]: "Section: Internal Compliance Memo (Pre-Account Opening)..."
#    >>> Match: Rule SECTION VIII.C.13. (Confidence: 38.74%)
#        Source: 40.json
#        Text: The term “Pre-existing Entity Account” means a Pre-existing Account held by one or more Entities....
#    >>> Match: Rule SECTION VIII.C.11. (Confidence: 37.89%)
#        Source: 40.json
#        Text: The term “Pre-existing Individual Account” means a Pre-existing Account held by one or more individuals....
#    >>> Match: Rule SECTION IV.A. (Confidence: 37.54%)
#        Source: 40.json
#        Text: With respect to New Individual Accounts, upon account opening, the Reporting Financial Institution must obtain a self-certification, which may be part...
#
# [Document Section]: "To: Onboarding Team
# From: Compliance Officer
# Date: December 5, 2025
# Subject: Approval for New Account Opening - Ref: A-900345 (Applicant)..."
#    >>> Match: Rule 5.5.1.(1) (Confidence: 25.13%)
#        Source: 7.json
#        Text: An Authorised Person must, subject to ‎(2), make the following appointments and ensure that they are held by one or more Approved Persons at all times...
#    >>> Match: Rule SECTION IV.A. (Confidence: 23.28%)
#        Source: 40.json
#        Text: With respect to New Individual Accounts, upon account opening, the Reporting Financial Institution must obtain a self-certification, which may be part...
#    >>> Match: Rule 5.3.6 (Confidence: 22.58%)
#        Source: 7.json
#        Text: Compliance Officer: The Compliance Officer function is carried out by an individual who is a Director, Partner or Senior Manager of an Authorised Pers...
#
# [Document Section]: "This new individual account (Ref: A-900345) for the German/Italian/UAE resident is approved for opening...."
#    >>> Match: Rule 5.5.2 (Confidence: 37.17%)
#        Source: 7.json
#        Text: The Approved Persons referred to in Rule ‎5.5.1(1)(a), ‎(c) and ‎(d) must be resident in the U.A.E....
#    >>> Match: Rule SECTION VIII.C.12. (Confidence: 34.29%)
#        Source: 40.json
#        Text: The term “New Individual Account” means a New Account held by one or more individuals....
#    >>> Match: Rule SECTION IV.A. (Confidence: 31.8%)
#        Source: 40.json
#        Text: With respect to New Individual Accounts, upon account opening, the Reporting Financial Institution must obtain a self-certification, which may be part...
#
# [Document Section]: "Compliance Notes:
# 1.  Self-Certification: The self-certification lists Germany and Italy as Reportable Jurisdictions.
# 2.  TIN: The German TIN was obtained. The Italian TIN was not obtained as the appl..."
#    >>> Match: Rule SECTION IV.B. (Confidence: 47.52%)
#        Source: 40.json
#        Text: If the self-certification establishes that the Account Holder is resident for tax purposes in a Reportable Jurisdiction, the Reporting Financial Insti...
#    >>> Match: Rule SECTION I.C. (Confidence: 44.79%)
#        Source: 40.json
#        Text: Notwithstanding subparagraph A(1), with respect to each Reportable Account that is a Pre- existing Account or with respect to each Financial Account t...
#    >>> Match: Rule SECTION I.D. (Confidence: 40.81%)
#        Source: 40.json
#        Text: Notwithstanding subparagraph A(1), the TIN is not required to be reported if (i) a TIN is not issued by the relevant Reportable Jurisdiction or (ii) t...
#
# Analyzing Document: T2.txt
# ------------------------------
#
# [Document Section]: "Preliminary Report on Prospective Petroleum Resources - Project Vulcan
# Issuer: Global Energy Explorations Inc. (GEEI), a Listed Company. Date of Disclosure: March 15, 2025 Subject: Discovery of potent..."
#    >>> Match: Rule 24) (Confidence: 33.77%)
#        Source: 31.json
#        Text: CONCEPTS RELATING TO THE DISCLOSURE OF PETROLEUM ACTIVITIES
# Petroleum Projects and materiality
# The factors that a Petroleum Reporting Entity (and for ...
#    >>> Match: Rule 12.7 (Confidence: 33.1%)
#        Source: 11.json
#        Text: Prospective Resources...
#    >>> Match: Rule 29) (Confidence: 32.72%)
#        Source: 31.json
#        Text: CONCEPTS RELATING TO THE DISCLOSURE OF PETROLEUM ACTIVITIES
# What is a material change in estimates?
# A material change could be in the form of material...
#
# [Document Section]: "Section 1: Petroleum Resource Estimates
# 1.1 Estimates Project Vulcan is estimated to hold 400 Million Barrels of Oil Equivalent (MMBOE) in total potentially recoverable resources. This figure aggregat..."
#    >>> Match: Rule 30) (Confidence: 42.89%)
#        Source: 31.json
#        Text: CONCEPTS RELATING TO THE DISCLOSURE OF PETROLEUM ACTIVITIES
# What is a material change in estimates?
# Whether there has been a material change in estima...
#    >>> Match: Rule 12.15.1 (Confidence: 39.04%)
#        Source: 11.json
#        Text: Competent Persons . A Petroleum Reporting Entity disclosing estimates of Prospective Resources, Contingent Resources or Petroleum Reserves must have t...
#    >>> Match: Rule 29) (Confidence: 38.04%)
#        Source: 31.json
#        Text: CONCEPTS RELATING TO THE DISCLOSURE OF PETROLEUM ACTIVITIES
# What is a material change in estimates?
# A material change could be in the form of material...
#
# [Document Section]: "1.2 Calculation Method The final aggregated estimate was calculated using a statistical aggregation of probability distributions applied across all five geological blocks within the Vulcan basin...."
#    >>> Match: Rule 64) (Confidence: 30.12%)
#        Source: 31.json
#        Text: INITIAL DISCLOSURE OF MATERIAL ESTIMATES.
# Disclosure of material estimates of Contingent Resources
# Pursuant to Rule 12.9.1(3), and similar to the trea...
#    >>> Match: Rule 72) (Confidence: 29.69%)
#        Source: 31.json
#        Text: INITIAL DISCLOSURE OF MATERIAL ESTIMATES.
# Disclosure of material estimates of Petroleum Reserves
# Pursuant to Rule 12.11.1(5), in circumstances where d...
#    >>> Match: Rule 6.7.2 (Confidence: 24.68%)
#        Source: 3.json
#        Text: Aggregation of Orders
# An Authorised Person may aggregate an order for a Client with an order for other Clients or with an order for its own account on...
#
# [Document Section]: "Section 2: Disclosure Content
# 2.1 Cautionary Statement The estimates in Section 1.1 are subject to high risk and uncertainty inherent in early-stage exploration. A full cautionary statement is include..."
#    >>> Match: Rule 114) (Confidence: 49.6%)
#        Source: 30.json
#        Text: SPECIFIC DISCLOSURE REQUIREMENTS
# Prominent, and proximate, cautionary statements
# After the first use of a cautionary statement within a disclosure, it...
#    >>> Match: Rule 59) (Confidence: 49.35%)
#        Source: 31.json
#        Text: INITIAL DISCLOSURE OF MATERIAL ESTIMATES.
# Prospective Resources - prominent, and proximate, cautionary statements
# After the first use of a cautionary ...
#    >>> Match: Rule 56) (Confidence: 40.71%)
#        Source: 31.json
#        Text: INITIAL DISCLOSURE OF MATERIAL ESTIMATES.
# Prospective Resources - prominent, and proximate, cautionary statements
# The FSRA considers that “proximate” ...
#
# [Document Section]: "2.2 Basis for Estimates The estimated 400 MMBOE includes quantities intended for GEEI’s lease fuel consumption (CiO - Company Internal Operations) which are not separated from the quantities available..."
#    >>> Match: Rule 12) (Confidence: 29.44%)
#        Source: 31.json
#        Text: DISCLOSURES TO BE PREPARED IN ACCORDANCE WITH THE PRMS . Examples of non-mandatory requirements that exist in the PRMS include:
#
# a)	Section 1.2.0.7, w...
#    >>> Match: Rule 29) (Confidence: 25.48%)
#        Source: 31.json
#        Text: CONCEPTS RELATING TO THE DISCLOSURE OF PETROLEUM ACTIVITIES
# What is a material change in estimates?
# A material change could be in the form of material...
#    >>> Match: Rule 12.11.1 (Confidence: 19.02%)
#        Source: 11.json
#        Text: A Petroleum Reporting Entity disclosing estimates of Petroleum Reserves must comply with the following:
# (1)	the term ‘reserves’ must only be used for ...
#
# [Document Section]: "2.3 Preparation and Sign-off The estimates presented in this report were compiled by GEEI's internal exploration team. The Lead Geologist, Mr. F. Drakes, confirmed the data is accurate. No prior writt..."
#    >>> Match: Rule 11.12.2 (Confidence: 26.22%)
#        Source: 11.json
#        Text: Competent Persons . The disclosure made in Rule 11.12.1 must only be made with the prior written consent of the Competent Person(s) as to the form and...
#    >>> Match: Rule 105) (Confidence: 21.91%)
#        Source: 30.json
#        Text: SPECIFIC DISCLOSURE REQUIREMENTS
# Competent Persons
# As required by Rule 11.12.2, the statement referred to in Rule 11.12.1 must only be disclosed with ...
#    >>> Match: Rule 37) (Confidence: 21.31%)
#        Source: 30.json
#        Text: EXPLORATION RESULTS . The disclosure of Exploration Results is common in the early stages of Exploration, when the quantity of data is generally not s...
#
# [Document Section]: "Section 3: Reporting Schedule
# 3.1 Quarterly Update GEEI's next quarterly activities report will be disclosed two months after the end of the current quarter to allow for the finalisation of geological..."
#    >>> Match: Rule 80) (Confidence: 39.61%)
#        Source: 31.json
#        Text: QUARTERLY DISCLOSURE OBLIGATIONS
# Quarterly Activity Reports
# The FSRA requires Petroleum Exploration Reporting Entities and Petroleum Production Report...
#    >>> Match: Rule 84) (Confidence: 39.28%)
#        Source: 31.json
#        Text: QUARTERLY DISCLOSURE OBLIGATIONS
# Quarterly Cash Reports - Petroleum Exploration Reporting Entities
# Petroleum Exploration Reporting Entities are requir...
#    >>> Match: Rule 124) (Confidence: 39.02%)
#        Source: 30.json
#        Text: QUARTERLY DISCLOSURE OBLIGATIONS
# Quarterly Cash Reports - Mining Exploration Reporting Entities
# Mining Exploration Reporting Entities are required, pu...
#
# Analyzing Document: T5.txt
# ------------------------------
#
# [Document Section]: "ENTITY: GLOBEX CLEARING SYSTEMS LTD. (ADGM Authorised Person, Fund Manager)
# RELATED ENTITY: GLOBEX MULTI-ASSET FUND (Domestic Public Fund)..."
#    >>> Match: Rule 8.1.1 (Confidence: 52.91%)
#        Source: 4.json
#        Text: The Fund Manager, or the Person proposing to be the Fund Manager, of a Domestic Fund which is a Public Fund but is not an Umbrella Fund, who is applyi...
#    >>> Match: Rule PART 2.3.1.1.(1) (Confidence: 52.28%)
#        Source: 6.json
#        Text: A Fund is either a Domestic Fund or a Foreign Fund....
#    >>> Match: Rule PART 2.3.2.1.(1) (Confidence: 50.09%)
#        Source: 6.json
#        Text: A Domestic Fund shall be one of the following types of Fund:
# (a)	a Public Fund;
# (b)	an Exempt Fund; or
# (c)	a Qualified Investor Fund....
#
# [Document Section]: "PART 1: PUBLIC FUND PROSPECTUS EXCERPT (Violating Fund Passporting Rules - Document 5)..."
#    >>> Match: Rule 3.2.2 (Confidence: 63.63%)
#        Source: 5.json
#        Text: If the Fund Manager of a Public Fund wishes to use the passporting procedures under these Rules, it must notify the Regulator of its intention that th...
#    >>> Match: Rule 8.6 (Confidence: 57.42%)
#        Source: 4.json
#        Text: Registering a Domestic Fund pursuant to the Fund Passporting Rules...
#    >>> Match: Rule 1.1.1 (Confidence: 55.75%)
#        Source: 5.json
#        Text: These Rules may be cited as the Fund Passporting Rules....
#
# [Document Section]: "DOCUMENT: Globex Multi-Asset Fund Public Prospectus V.3
# HOME REGULATOR: ADGM FSRA..."
#    >>> Match: Rule 3.2.1 (Confidence: 46.86%)
#        Source: 5.json
#        Text: This Section applies if the Regulator is the Home Regulator of a Public Fund....
#    >>> Match: Rule 6.2.2 (Confidence: 35.03%)
#        Source: 5.json
#        Text: A Passported Fund must at all times have appointed a Fund Manager that is authorised by its Home Regulator to conduct the activity of fund management ...
#    >>> Match: Rule 3.3.1.(1) (Confidence: 34.87%)
#        Source: 11.json
#        Text: A Person intending to have Units admitted to trading on a Recognised Investment Exchange must, subject to (2), and (3) submit to the Regulator:
# (a)	a ...
#
# [Document Section]: "No regulatory authority in the UAE has any responsibility for reviewing or verifying this prospectus or any other documents in connection with the promotion of this fund. Accordingly, no regulatory au..."
#    >>> Match: Rule 3.2.3 (Confidence: 79.36%)
#        Source: 5.json
#        Text: The notice must:
# (a)	be in such form as the Regulator may from time to time determine;
# (b)	include a certification, given on behalf of the Fund Manage...
#    >>> Match: Rule 3.1.3 (Confidence: 73.2%)
#        Source: 5.json
#        Text: The notice must:
# (a)	be in such form as the Regulator may from time to time determine;
# (b)	identify the Host Jurisdiction(s) in which the Private Fund...
#    >>> Match: Rule PART 4.9.5.3.Mandatory_statement.(1) (Confidence: 49.92%)
#        Source: 6.json
#        Text: A Fund Manager of a Public Fund or an Exempt Fund must include in the Fund's Prospectus, the following statement displayed prominently on its front pa...
#
# [Document Section]: "The Key Investor Information Document (KIID) is available in English on the Fund Manager's website. Due to translation complexities, an Arabic version of the KIID is not provided at this time...."
#    >>> Match: Rule 3.3.3.(3) (Confidence: 28.04%)
#        Source: 11.json
#        Text: Where the Offer document referred to in (1) is not in the English language, it must be accompanied by an English translation acceptable to the Regulat...
#    >>> Match: Rule 13) (Confidence: 26.29%)
#        Source: 28.json
#        Text: IMPORTANCE OF CONTINUOUS DISCLOSURE
# Disclosures made via the FSRA’s disclosure platform must be made in the English language.  If an original document...
#    >>> Match: Rule 7.4.4 (Confidence: 25.42%)
#        Source: 10.json
#        Text: Language of notice . Any notice to be given or information to be supplied under these notification rules must be supplied in English, and any document...
#
# [Document Section]: "Globex Multi-Asset Fund (a Public Fund) has appointed a Custodian to hold all Fund Property. This Custodian is Globex Clearing Systems Ltd., which is the Fund Manager, due to internal efficiency and c..."
#    >>> Match: Rule 6.5.3 (Confidence: 58.89%)
#        Source: 5.json
#        Text: The Fund Manager of a Passported Fund that is a Public Fund must ensure that, except in the case of a property fund, a custodian is appointed at all t...
#    >>> Match: Rule 14.1.3.Guidance.4. (Confidence: 52.03%)
#        Source: 3.json
#        Text: A Fund Manager, Fund Administrator, Custodian or Trustee that holds Fund Property must comply with the Fund Rules rather than the Client Money Rules....
#    >>> Match: Rule PART 5.12.12.1 (Confidence: 48.6%)
#        Source: 6.json
#        Text: Fund Manager.In accordance with the Delegation Agreement, the Fund Manager:
# (a)	must (save as otherwise permitted by these Rules) register the legal t...
#
# [Document Section]: "PART 2: SPOT COMMODITY DELIVERY & STORAGE RULES (Violating Spot Commodities Guidance - Document 34)..."
#    >>> Match: Rule 3.19 (Confidence: 56.81%)
#        Source: 4.json
#        Text: Spot Commodities...
#    >>> Match: Rule 31) (Confidence: 53.73%)
#        Source: 34.json
#        Text: REGULATORY REQUIREMENTS - SPOT COMMODITY ACTIVITIES
# Spot Commodity Title
# The FSRA only permits activities involving a Spot Commodity Title where the u...
#    >>> Match: Rule 26) (Confidence: 53.0%)
#        Source: 34.json
#        Text: REGULATORY REQUIREMENTS - SPOT COMMODITY ACTIVITIES
# Spot Commodities and Accepted Spot Commodities
# Accordingly, for the purposes of COBS Rules 22.2.2(...
#
# [Document Section]: "ENTITY: GLOBEX CLEARING SYSTEMS - COMMODITY TRADING FACILITY RULES..."
#    >>> Match: Rule Schedule 1.Part 2.Chapter 9.54. (Confidence: 46.46%)
#        Source: 17.json
#        Text: The activities. Operating a Multilateral Trading Facility or Organised Trading Facility
# The activities of Operating a Multilateral Trading Facility or...
#    >>> Match: Rule Schedule 1.Part 2.Chapter 2.19. (Confidence: 43.96%)
#        Source: 17.json
#        Text: Exclusions. Arrangements which amount to Operating a Multilateral Trading Facility or Organised Trading Facility
# There are excluded from paragraph ‎16...
#    >>> Match: Rule 5.2.14 (Confidence: 42.51%)
#        Source: 7.json
#        Text: In assessing an application for a Financial Services Permission authorising the applicant to Operate a Multilateral Trading Facility or an Organised T...
#
# [Document Section]: "Globex Clearing Systems (the Authorised Person) will manage, monitor, and control the third-party storage facility used for all Accepted Spot Commodities...."
#    >>> Match: Rule 22.2 (Confidence: 48.98%)
#        Source: 3.json
#        Text: Accepted Spot Commodities...
#    >>> Match: Rule 28) (Confidence: 45.56%)
#        Source: 34.json
#        Text: REGULATORY REQUIREMENTS - SPOT COMMODITY ACTIVITIES
# Spot Commodities and Accepted Spot Commodities
# Due to Accepted Spot Commodities being determined f...
#    >>> Match: Rule 22.4.3 (Confidence: 42.47%)
#        Source: 3.json
#        Text: Storage Facilities. An Authorised Person must have arrangements in place for the approval, management, monitoring and control for Accepted Spot Commod...
#
# [Document Section]: "In the event of negative circumstances or market compromise at the storage facility, Globex Clearing Systems retains the power to compel the storage facility to take action. However, the Authorised Pe..."
#    >>> Match: Rule 38) (Confidence: 61.64%)
#        Source: 34.json
#        Text: REGULATORY REQUIREMENTS - SPOT COMMODITY ACTIVITIES
# Delivery & Storage
# Pursuant to COBS Rule 22.4.3, an Authorised Person must have arrangements in pl...
#    >>> Match: Rule 65) (Confidence: 48.76%)
#        Source: 34.json
#        Text: REGULATORY REQUIREMENTS - SPOT COMMODITY ACTIVITIES
# Sanctions
# Pursuant to AML Rule 11.2.1(1), an Authorised Person must have arrangements in place to ...
#    >>> Match: Rule 39) (Confidence: 42.69%)
#        Source: 34.json
#        Text: REGULATORY REQUIREMENTS - SPOT COMMODITY ACTIVITIES
# Delivery & Storage
# Pursuant to COBS Rule 22.4.3(e), an Authorised Person should establish that a s...
#
# [Document Section]: "Globex Clearing Systems (as an MTF operator) shall maintain regulatory capital equivalent to 6 months of operational expenses...."
#    >>> Match: Rule 3.2.1 (Confidence: 45.51%)
#        Source: 10.json
#        Text: A Recognised Investment Exchange shall hold the following capital:
# (a)	an amount equal to 6 months' operational expenses; plus
# (b)	unless the Regulato...
#    >>> Match: Rule 33) (Confidence: 44.41%)
#        Source: 19.json
#        Text: REGULATORY REQUIREMENTS FOR AUTHORISED PERSONS ENGAGED IN REGULATED ACTIVITIES IN RELATION TO VIRTUAL ASSETS
# Capital Requirements
# Subject to the above...
#    >>> Match: Rule 8.4.1 (Confidence: 37.42%)
#        Source: 3.json
#        Text: An MTF Operator or OTF Operator must not introduce a liquidity incentive scheme unless
# (a)	participation of such a scheme is limited to members or any...
#
# [Document Section]: "PART 3: API SPECIFICATION FOR CLEARING SERVICE (Violating API Guidance - Document 21)..."
#    >>> Match: Rule 40) (Confidence: 57.96%)
#        Source: 21.json
#        Text: API REQUIREMENTS
# API Documentation
# At a high level the fundamentals that need to be documented in the API contract in order for both parties to be abl...
#    >>> Match: Rule 39) (Confidence: 56.52%)
#        Source: 21.json
#        Text: API REQUIREMENTS
# API Documentation
# The API documentation (or ‘contract’) describes all aspects of the API in order to enable successful interaction be...
#    >>> Match: Rule APPENDIX.Appendix B: (Confidence: 54.77%)
#        Source: 21.json
#        Text: API Standards...
#
# [Document Section]: "API SERVICE: GLOBEX_CLEARED_TRADE_FEED / V1.0
# API TYPE: Partner API (SOAP)..."
#    >>> Match: Rule 40) (Confidence: 65.27%)
#        Source: 21.json
#        Text: API REQUIREMENTS
# API Documentation
# At a high level the fundamentals that need to be documented in the API contract in order for both parties to be abl...
#    >>> Match: Rule 39) (Confidence: 64.14%)
#        Source: 21.json
#        Text: API REQUIREMENTS
# API Documentation
# The API documentation (or ‘contract’) describes all aspects of the API in order to enable successful interaction be...
#    >>> Match: Rule APPENDIX.Appendix B: (Confidence: 62.16%)
#        Source: 21.json
#        Text: API Standards...
#
# [Document Section]: "Authentication: SOAP uses a unique XML format which provides built-in security features. Therefore, to ensure maximum interoperability and minimal latency for our Partners, the GLOBEX_CLEARED_TRADE_FE..."
#    >>> Match: Rule 23) (Confidence: 27.44%)
#        Source: 21.json
#        Text: BACKGROUND
# The types of APIs
# SOAP is another methodology and differs from REST especially in that it only uses one format, XML. SOAP also allows an ap...
#    >>> Match: Rule 50) (Confidence: 22.61%)
#        Source: 21.json
#        Text: API REQUIREMENTS
# Credentials management
# Authentication, authorisation and encryption are fundamental to the security of APIs. In terms of authenticati...
#    >>> Match: Rule APPENDIX.Appendix B:.66) (Confidence: 21.33%)
#        Source: 21.json
#        Text: The following describes the standards that should be applied when building APIs.
# /Table Start
# Area/Subject	Standard
# Publishing of technical, engagemen...
#
# [Document Section]: "The API is fully developed and operational. All future functionality will be added to the current V1.0 endpoint. Policies for change management are currently under internal review and will be formaliz..."
#    >>> Match: Rule 40) (Confidence: 21.69%)
#        Source: 21.json
#        Text: API REQUIREMENTS
# API Documentation
# At a high level the fundamentals that need to be documented in the API contract in order for both parties to be abl...
#    >>> Match: Rule APP4.A4.7.11 (Confidence: 21.57%)
#        Source: 13.json
#        Text: Not currently in use....
#    >>> Match: Rule 61) (Confidence: 20.39%)
#        Source: 21.json
#        Text: API REQUIREMENTS
# Version control
# Versioning and change control is very important and needs to be managed effectively. As such, organisations should ha...
#
# Analyzing Document: T4.txt
# ------------------------------
#
# [Document Section]: "Compliance Self-Assessment & Fee Declaration (Spot-ESG Corp.)..."
#    >>> Match: Rule 8.5.1 (Confidence: 28.1%)
#        Source: 4.json
#        Text: A Foreign Fund Manager providing a declaration to the Regulator of its intention to manage a Domestic Fund must pay to Regulator a fee of $20,000....
#    >>> Match: Rule 7. (Confidence: 25.8%)
#        Source: 25.json
#        Text: ESG disclosures by FSRA fund and asset managers – AUM threshold
#
# The ESG disclosures by FSRA-licensed fund and asset managers are entity-level disclos...
#    >>> Match: Rule Part 5.Chapter 2.30. (Confidence: 25.73%)
#        Source: 14.json
#        Text: Assessment by the Regulator...
#
# [Document Section]: "Entity Name: Spot-ESG Corp. (An ADGM Limited Company and Applicant for an FSP to operate an MTF)
# Date of Submission: December 8, 2025
# Financial Year End: December 31, 2024..."
#    >>> Match: Rule SECTION V.D.1. (Confidence: 36.93%)
#        Source: 40.json
#        Text: Review of Pre-existing Entity Accounts with an aggregate account balance or value that exceeds USD 250 000 as of 31 December 2016, must be completed b...
#    >>> Match: Rule SECTION VIII.C.15. (Confidence: 36.08%)
#        Source: 40.json
#        Text: The term “High Value Account” means a Pre-existing Individual Account with an aggregate balance or value that exceeds USD 1 000 000 as of 31 December ...
#    >>> Match: Rule SECTION III.D. (Confidence: 29.66%)
#        Source: 40.json
#        Text: Review of Pre-existing High Value Individual Accounts must be completed by 31 December 2017 and review of Pre-existing Lower Value Individual Accounts...
#
# [Document Section]: "Part 1: Regulatory Compliance & Operational Plan (Spot Commodities)..."
#    >>> Match: Rule 3.19 (Confidence: 60.09%)
#        Source: 4.json
#        Text: Spot Commodities...
#    >>> Match: Rule 28) (Confidence: 52.89%)
#        Source: 34.json
#        Text: REGULATORY REQUIREMENTS - SPOT COMMODITY ACTIVITIES
# Spot Commodities and Accepted Spot Commodities
# Due to Accepted Spot Commodities being determined f...
#    >>> Match: Rule 22) (Confidence: 52.33%)
#        Source: 34.json
#        Text: REGULATORY REQUIREMENTS - SPOT COMMODITY ACTIVITIES
# Spot Commodities and Accepted Spot Commodities
# or the purposes of the Spot Commodities Framework, ...
#
# [Document Section]: "| Requirement | Compliance Status | Rationale/Evidence Provided to FSRA |
# | Delivery Jurisdiction | Compliant | Delivery will take place in the Port of Djibouti, where the storage facility operates un..."
#    >>> Match: Rule 22.4.2 (Confidence: 40.83%)
#        Source: 3.json
#        Text: For the purposes of Rule 22.4.1, any delivery and/or storage facility used by an Authorised Person must be a facility in relation to which –
# (a)	where...
#    >>> Match: Rule 42) (Confidence: 39.56%)
#        Source: 34.json
#        Text: REGULATORY REQUIREMENTS - SPOT COMMODITY ACTIVITIES
# Delivery & Storage
# Pursuant to COBS Rule 22.4.5, an Authorised Person must have arrangements in pl...
#    >>> Match: Rule 36) (Confidence: 38.4%)
#        Source: 34.json
#        Text: REGULATORY REQUIREMENTS - SPOT COMMODITY ACTIVITIES
# Delivery & Storage
# COBS Rules 22.4.2(c)(i) and (ii) require a delivery and/or storage facility to ...
#
# [Document Section]: "Spot-ESG Corp. is applying for a Financial Services Permission to Operate a Multilateral Trading Facility (MTF) using Accepted Spot Commodities and simultaneously requests permission for the Regulated..."
#    >>> Match: Rule 22.2 (Confidence: 39.69%)
#        Source: 3.json
#        Text: Accepted Spot Commodities...
#    >>> Match: Rule 19) (Confidence: 39.02%)
#        Source: 34.json
#        Text: PURPOSE & FEATURES OF THE SPOT COMMODITIES FRAMEWORK.
# Regulated Activities using Spot Commodities.
# The principal Rules for Authorised Persons conducti...
#    >>> Match: Rule 22.2.1 (Confidence: 38.48%)
#        Source: 3.json
#        Text: An Authorised Person conducting a Regulated Activity in relation to Spot Commodities must only allow Accepted Spot Commodities....
#
# [Document Section]: "Declaration: The total application fee due is $125,000 USD...."
#    >>> Match: Rule 113) (Confidence: 44.38%)
#        Source: 34.json
#        Text: FEES
# Cumulative application of Fees
# In practice, and to further clarify, this results in several scenarios for FEES relating to Spot Commodities activ...
#    >>> Match: Rule 4.1.1 (Confidence: 43.56%)
#        Source: 4.json
#        Text: An Applicant for recognition as either a Recognised Investment Exchange or a Recognised Clearing House must pay to the Regulator an application fee of...
#    >>> Match: Rule 184) (Confidence: 42.32%)
#        Source: 19.json
#        Text: FEES
# Cumulative application of Fees
# In practice, and to further clarify, this results in several scenarios for FEES in relation to Virtual Asset activ...
#
# [Document Section]: "| Financial Metric | Value (FYE 2024) | Threshold Condition Met? |
# | Turnover | US$ 75,000,000 | YES (Exceeds US$ 68 million) |
# | Date of Incorporation | October 1, 2023 | NO (Less than 3 years) |..."
#    >>> Match: Rule 3.5.12 (Confidence: 30.59%)
#        Source: 10.json
#        Text: Orders large in scale compared with normal market size
# /Table Start
# Class in terms of average daily turnover (ADT, in USD)	ADT <= 500,000	500 000 < AD...
#    >>> Match: Rule 5. (Confidence: 27.92%)
#        Source: 25.json
#        Text: Threshold conditions
#
# A company incorporated in or continued into ADGM will be required to comply with the ESG Disclosures Framework if it satisfies t...
#    >>> Match: Rule APP7.Guidance.2. (Confidence: 26.1%)
#        Source: 13.json
#        Text: The application of various components of the rules on Operational Risk to Authorised Persons with a Financial Services Permission to carry out various...
#
# [Document Section]: "Spot-ESG Corp. is an in-scope company due to meeting the turnover threshold...."
#    >>> Match: Rule 5. (Confidence: 56.55%)
#        Source: 25.json
#        Text: Threshold conditions
#
# A company incorporated in or continued into ADGM will be required to comply with the ESG Disclosures Framework if it satisfies t...
#    >>> Match: Rule 9. (Confidence: 41.03%)
#        Source: 25.json
#        Text: Group annual accounts
#
# A parent company that prepares group accounts should prepare ESG disclosures on the basis of the turnover of the group for the ...
#    >>> Match: Rule 6. (Confidence: 40.99%)
#        Source: 25.json
#        Text: ESG disclosures by companies - turnover threshold
#
# For the purposes of the CR, ‘turnover’ is defined as: the amounts derived from the provision of goo...
#
# [Document Section]: "Submission Plan: As the company is still developing its operational infrastructure, the Board has formally determined to not submit the required ESG disclosures for the FYE 2024. The company will inst..."
#    >>> Match: Rule 10. (Confidence: 27.49%)
#        Source: 25.json
#        Text: Disclosures standard
#
# A company which is required to prepare and submit ESG disclosures must prepare its submissions consistent with a standard which ...
#    >>> Match: Rule 14. (Confidence: 26.07%)
#        Source: 25.json
#        Text: Publication of ESG disclosures
#
# The ADGM encourages companies to make their ESG disclosures publicly available in the spirit of transparency and advan...
#    >>> Match: Rule 12. (Confidence: 25.67%)
#        Source: 25.json
#        Text: Non-submission of ESG disclosures by in-scope companies
#
# The ESG Disclosures Framework offers flexibility through its ‘comply or explain’ approach, wh...
